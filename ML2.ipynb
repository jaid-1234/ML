# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing
housing_data=fetch_california_housing(as_frame=True)
import warnings
warnings.filterwarnings('ignore')

# %%
data=housing_data['data']
data['MedHousVal']=housing_data['target']

# %%
print("Computing the correlation matrix..")
correlation_matrix=data.corr()
print(correlation_matrix)
# Out:
# Computing the correlation matrix..
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHousVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude  MedHousVal
# MedInc     -0.079809  -0.015176    0.688075
# HouseAge    0.011173  -0.108197    0.105623
# AveRooms    0.106389  -0.027540    0.151948
# ...

# %%
print("visualizing the correlation matrix using heat map...")
sns.heatmap(correlation_matrix,annot=True,fmt=".2f",cmap="coolwarm",cbar=True,square=True)
plt.title("Correlation_matrix Heat Map")
plt.show()
# Out:
# visualizing the correlation matrix using heat map...

# %%
print("Creating a pair plot to visualize pairwise realation ship between features...")
sns.pairplot(data,diag_kind='kde',corner=True)
plt.show()
# Out:
# Creating a pair plot to visualize pairwise realation ship between features...
